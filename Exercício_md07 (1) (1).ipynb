# %% [markdown]
# ### Tarefa 01

# %%
dados_tratados.to_csv('dados_tratados.csv')

# %%
dados=pd.read_csv('/content/dados_tratados.csv')
dados.set_index('ID',inplace=True)
dados
# Out:
#          CNT_CHILDREN  AMT_INCOME_TOTAL  DAYS_BIRTH  DAYS_EMPLOYED  \
# ID
# 5008806             0          112500.0    -21474.0        -1134.0
# 5008806             0          112500.0    -21474.0        -1134.0
# 5008806             0          112500.0    -21474.0        -1134.0
# 5008806             0          112500.0    -21474.0        -1134.0
# 5008806             0          112500.0    -21474.0        -1134.0
# ...               ...               ...         ...            ...
# 5118649             2          270000.0    -10425.0        -2745.0
# 5118650             2          270000.0    -10425.0        -2745.0
# 5118650             2          270000.0    -10425.0        -2745.0
# 5118650             2          270000.0    -10425.0        -2745.0
# 5118650             2          270000.0    -10425.0        -2745.0
#
#          FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL  CNT_FAM_MEMBERS  \
# ID
# ...

# %% [markdown]
# ### Tarefa 02

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
x=dados.drop('STATUS',axis=1).values
y=dados['STATUS'].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x,y,train_size=0.7,random_state=42)

# %%
clf=DecisionTreeClassifier()
modelo=clf.fit(X_train,y_train)
y_pred=modelo.predict(X_test)
#vizualizar a arvore

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[129972     50]
#  [   137     60]]

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.99856395764059

# %% [markdown]
# ### Tarefa 03

# %%
clf1=DecisionTreeClassifier(max_depth=10,min_samples_split=5, random_state=123)
modelo1=clf1.fit(X_train,y_train)
y_pred1=modelo1.predict(X_test)

# %%
print(confusion_matrix(y_test,y_pred1))
# Out:
# [[129995     27]
#  [   143     54]]

# %%
print(accuracy_score(y_test,y_pred1))
# Out:
# 0.9986945069459909

# %% [markdown]
# * O modelo não conseguiu classificar nem 0.1% dos contratos  (0.0069882260038877835)

# %% [markdown]
# * Se classificasse todos os contratos como **bons** o modelo acertaria 100% uma vez que esse modelo ficou enviesado por conta do desequilibrio das classes.
