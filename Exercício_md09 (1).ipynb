# %% [markdown]
# ### Carregando os dados

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df=pd.read_csv('/content/b1abb33c4f.csv')
df.head()
# Out:
#    ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 0       1  2679477.0      110001        1        19        5.0
# 1       1  2679477.0      110001        1        29        2.0
# 2       1  2679477.0      110001        1        37        9.0
# 3       1  2516500.0      110001        1        30        5.0
# 4       1  2516500.0      110001        1        30        2.0
#
#             ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK  \
# 0      8 a 11 anos         NaN         0.0         0.0  ...           5
# 1      8 a 11 anos    999992.0         1.0         0.0  ...           5
# 2      8 a 11 anos    513205.0         2.0         0.0  ...           5
# 3  12 anos ou mais    231205.0         0.0         0.0  ...           4
# 4      8 a 11 anos    999992.0         1.0         0.0  ...           5
#
#   CONTADOR munResStatus munResTipo               munResNome  munResUf  \
# 0        1        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27028 entries, 0 to 27027
# Data columns (total 71 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ORIGEM        27028 non-null  int64
#  1   CODESTAB      26913 non-null  float64
#  2   CODMUNNASC    27028 non-null  int64
#  3   LOCNASC       27028 non-null  int64
#  4   IDADEMAE      27028 non-null  int64
#  5   ESTCIVMAE     26711 non-null  float64
#  6   ESCMAE        26716 non-null  object
#  7   CODOCUPMAE    24121 non-null  float64
#  8   QTDFILVIVO    25455 non-null  float64
#  9   QTDFILMORT    24930 non-null  float64
#  10  CODMUNRES     27028 non-null  int64
#  11  GESTACAO      25796 non-null  object
#  12  GRAVIDEZ      26949 non-null  object
#  13  PARTO         26979 non-null  object
#  14  CONSULTAS     27028 non-null  int64
#  15  DTNASC        27028 non-null  object
#  16  HORANASC      27007 non-null  float64
#  17  SEXO          27024 non-null  object
# ...

# %% [markdown]
# ### Tarefa 01

# %%
df.loc[(df['munResLat']> -10.5),'faixa']='acima'
df.loc[(df['munResLat']< -10.5),'faixa']='abaixo'

# %%
df.groupby(['faixa'])['QTDGESTANT'].describe()
# Out:
#           count      mean       std  min  25%  50%  75%   max
# faixa
# abaixo  12901.0  1.186032  1.304777  0.0  0.0  1.0  2.0  15.0
# acima   12914.0  1.364024  1.492482  0.0  0.0  1.0  2.0  52.0

# %%
df.groupby(['faixa'])['QTDFILMORT'].describe()
# Out:
#           count      mean       std  min  25%  50%  75%   max
# faixa
# abaixo  12803.0  0.242521  0.599430  0.0  0.0  0.0  0.0  28.0
# acima   12126.0  0.291770  0.627856  0.0  0.0  0.0  0.0   9.0

# %% [markdown]
# ### Tarefa 02

# %%
df.loc[(df['munResArea']> 3000),'faixa1']='acima'
df.loc[(df['munResArea']< 3000),'faixa1']='abaixo'

# %%
df.groupby(['faixa1'])['ESTCIVMAE'].describe()
# Out:
#           count      mean       std  min  25%  50%  75%  max
# faixa1
# abaixo   5173.0  2.578774  1.582431  1.0  1.0  2.0  5.0  9.0
# acima   21537.0  2.537169  1.691778  1.0  1.0  2.0  5.0  9.0

# %%
df.groupby(['faixa1'])['CONSULTAS'].describe()
# Out:
#           count      mean       std  min  25%  50%  75%  max
# faixa1
# abaixo   5219.0  3.740180  0.607492  1.0  4.0  4.0  4.0  9.0
# acima   21808.0  3.537326  0.820967  1.0  3.0  4.0  4.0  9.0

# %% [markdown]
# ### Tarefa 03

# %%
df.loc[(df['munResAlt']> 153),'faixa3']='acima'
df.loc[(df['munResAlt']< 153),'faixa3']='abaixo'

# %%
df.groupby(['faixa3'])['TPNASCASSI'].describe()
# Out:
#           count      mean       std  min  25%  50%  75%  max
# faixa3
# abaixo  13010.0  1.192237  0.483426  1.0  1.0  1.0  1.0  9.0
# acima   13373.0  1.104838  0.360208  1.0  1.0  1.0  1.0  9.0

# %%
df.groupby(['faixa3'])['KOTELCHUCK'].describe()
# Out:
#           count      mean       std  min  25%  50%  75%  max
# faixa3
# abaixo  13039.0  5.389140  2.500460  1.0  4.0  5.0  9.0  9.0
# acima   13405.0  4.591197  1.466623  1.0  4.0  5.0  5.0  9.0

# %% [markdown]
# ### Tarefa 04

# %%
imediatista=df.loc[(df['munResNome']=='Porto Velho') | (df['munResNome']=='Ariquemes') | (df['munResNome']=='Jaru') | (df['munResNome']=='Ji-Paraná') | (df['munResNome']=='Cacoal') | (df['munResNome']=='Vilhena')]
imediatista.groupby(['munResNome'])['IDADEMAE'].mean().sort_values(ascending=False).plot.bar()

# %% [markdown]
# ### Tarefa 05

# %%
#Tive uma certa dificuldade nessa ultima questão.
