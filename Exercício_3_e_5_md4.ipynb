# %% [markdown]
# ### Tarefa 01

# %%
import numpy as np
import pandas as pd

# %%
gabarito=[['matematica',24],['portugues',18],['geografia',8],['ingles',8],['historia',8],['fisica',12],['quimica',12]]
gabarito=pd.DataFrame(gabarito,columns=['disciplina','n_questoes'])
gabarito
# Out:
#    disciplina  n_questoes
# 0  matematica          24
# 1   portugues          18
# 2   geografia           8
# 3      ingles           8
# 4    historia           8
# 5      fisica          12
# 6     quimica          12

# %%
gabarito['pontos'].sum()
# Out:
# 90

# %%
np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['Qt_acertos'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])
df_qui_perc=(df_qui/12)*100
df_fis_perc=(df_fis/12)*100
df_his_perc=(df_his/8)*100
df_ing_perc=(df_ing/8)*100
df_geo_perc=(df_geo/8)*100
df_por_perc=(df_por/18)*100
df_mat_perc=(df_mat/24)*100

df_qui_perc
# Out:
#     Qt_acertos
# 0    25.000000
# 1    66.666667
# 2    33.333333
# 3    66.666667
# 4    25.000000
# ..         ...
# 95   25.000000
# 96   25.000000
# 97   41.666667
# 98   91.666667
# 99   16.666667
#
# [100 rows x 1 columns]

# %%
total=df_qui+df_fis+df_his+df_ing+df_geo+df_por+df_mat
total/90
# Out:
#     Qt_acertos
# 0     0.388889
# 1     0.533333
# 2     0.555556
# 3     0.355556
# 4     0.333333
# ..         ...
# 95    0.377778
# 96    0.300000
# 97    0.444444
# 98    0.444444
# 99    0.466667
#
# [100 rows x 1 columns]

# %%
aprovados=total[total>45]
aprovados.dropna(inplace=True)
aprovados.shape
# Out:
# (31, 1)

# %% [markdown]
# ### Tarefa 02

# %%
df_eliminados = total[(df_mat['Qt_acertos'] == 0) | 
                      (df_fis['Qt_acertos'] == 0) | 
                      (df_qui['Qt_acertos'] == 0)]

df_eliminados.head()
# Out:
#     Qt_acertos
# 3           32
# 6           29
# 10          31
# 12          42
# 14          31

# %% [markdown]
# ### Tarefa 03

# %%
import pandas as pd

# %%
#Segunda questão
base = pd.read_csv('/content/registros de vacinacao covid ACRE.csv', sep=';')
base
# Out:
#                                       document_id  \
# 0       b19cd280-474c-4c22-a35d-8c06bc04a4e0-i0b0
# 1       a1acc0b6-1cf6-4c4b-adcb-06b473a0faaf-i0b0
# 2       af279a98-ba1f-47ea-8214-314a98040b0d-i0b0
# 3       4879308e-5050-46bb-b8e2-11fa5646a05c-i0b0
# 4       000e911b-e3a4-4114-a735-d1f2e6e3797f-i0b0
# ...                                           ...
# 169066  1d8f6ea9-d3f5-4882-9fe4-9d2f3ef88d77-i0b0
# 169067  77ff98a4-79fb-47c9-aafa-8bf45708c4bc-i0b0
# 169068  1da067bc-9989-4fa4-8838-e1e40cdfeebf-i0b0
# 169069  eacc22e0-6f78-460f-a8e7-d85c6129951e-i0b0
# 169070  02795bd0-b1a7-49c1-83ca-90a9f9b4b794-i0b0
#
#                                               paciente_id  paciente_idade  \
# 0       2e091c9a37d3f50d1d705fc80c6448c6fc69b44da9e936...              69
# 1       f4e17a9e5354cb45e223d85eda02fb2f76048c801675f5...              81
# 2       6734b26bccf826130ebffa66575977bbe71477b12bcf42...              69
# ...

# %%
#1. Quantas vacinas estão registradas nessa base?  
print(f'Essa base de dados possue: {base.shape}')
# Out:
# Essa base de dados possue: (169071, 34)

# %%
#2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)  
base['paciente_id'].nunique()
# Out:
# 120517

# %%
#3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. 
primeira_dose=base[base['vacina_descricao_dose']=='\xa0\xa0\xa0\xa01ª\xa0Dose']
primeira_dose.shape
# Out:
# (120939, 34)

# %%
#4. Quantos pacientes com menos de 18 anos foram vacinados?  
paciente_menos_18=base[base['paciente_idade']<18]
paciente_menos_18.nunique().shape
# Out:
# (34,)

# %%
#5. Quantos estabelecimentos aplicaram vacina no Acre?
base['estalecimento_nofantasia'].unique().shape
# Out:
# (103,)

# %% [markdown]
# ### Tarefa 04

# %%
estabelecimento=paciente_menos_18['estalecimento_nofantasia'].value_counts()
df_local=pd.DataFrame(estabelecimento)
df_local.reset_index(inplace=True)
df_local.columns=['estabelecimento','qtd_aplicada']
df_local.head()
# Out:
#                                      estabelecimento  qtd_aplicada
# 0                  POLO BASE DE MARECHAL THAUMATURGO             9
# 1                      UBS VICENTE VARELA DE ALMEIDA             8
# 2                                 POLO BASE DE FEIJO             6
# 3  DEPARTAMENTO DE VIGILANCIA EPIDEMIOLOGICA E AM...             4
# 4                                 POLO BASE INDIGENA             4

# %%
#1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.  
df_local.copy()
# Out:
#                                       estabelecimento  qtd_aplicada
# 0                   POLO BASE DE MARECHAL THAUMATURGO             9
# 1                       UBS VICENTE VARELA DE ALMEIDA             8
# 2                                  POLO BASE DE FEIJO             6
# 3   DEPARTAMENTO DE VIGILANCIA EPIDEMIOLOGICA E AM...             4
# 4                                  POLO BASE INDIGENA             4
# 5                           POLO BASE DE ASSIS BRASIL             3
# 6    SECRETARIA MUNICIPAL DE SAUDE DE CRUZEIRO DO SUL             3
# 7                   CENTRO DE SAUDE DIAMANTINO MACEDO             3
# 8                            POLO BASE DE MANCIO LIMA             3
# 9                           POLO BASE DE PORTO WALTER             2
# 10  UNIDADE ASSISTENCIAL A SAUDE INDIGENA DE TARAU...             2
# 11                     POLO INDIGENA DE MANOEL URBANO             2
# 12    DISTRITO SANITARIO ESPECIAL INDIGENA ALTO PURUS             1
# ...

# %%
#2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**  
lista_colunas=paciente_menos_18.columns
lista_colunas
# Out:
# Index(['document_id', 'paciente_id', 'paciente_idade',
#        'paciente_datanascimento', 'paciente_enumsexobiologico',
#        'paciente_racacor_codigo', 'paciente_racacor_valor',
#        'paciente_endereco_coibgemunicipio', 'paciente_endereco_copais',
#        'paciente_endereco_nmmunicipio', 'paciente_endereco_nmpais',
#        'paciente_endereco_uf', 'paciente_endereco_cep',
#        'paciente_nacionalidade_enumnacionalidade', 'estabelecimento_valor',
#        'estabelecimento_razaosocial', 'estalecimento_nofantasia',
#        'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
#        'estabelecimento_uf', 'vacina_grupoatendimento_codigo',
#        'vacina_grupoatendimento_nome', 'vacina_categoria_codigo',
#        'vacina_categoria_nome', 'vacina_lote', 'vacina_fabricante_nome',
#        'vacina_fabricante_referencia', 'vacina_dataaplicacao',
#        'vacina_descricao_dose', 'vacina_codigo', 'vacina_nome',
# ...

# %%
#3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
paciente_menos_18['vacina_categoria_nome'].value_counts()
# Out:
# Povos Indígenas                     33
# Trabalhadores de Saúde               9
# Povos e Comunidades Tradicionais     9
# Comorbidades                         2
# Faixa Etária                         1
# Name: vacina_categoria_nome, dtype: int64

# %%
#4. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento,faça uma lista com esses valores.
lista_estabelecimento=['estabelecimento_valor','estabelecimento_razaosocial', 'estalecimento_nofantasia',
                       'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome','estabelecimento_uf']

# %%
#5. usando o método *.loc*, selecione somente essas variáveis  

nova_lista_estab=paciente_menos_18.loc[:,lista_estabelecimento]
nova_lista_estab.head()
# Out:
#        estabelecimento_valor  \
# 1567                 2001314
# 6250                 6917291
# 9569                 6159087
# 11338                2000040
# 15144                7625855
#
#                              estabelecimento_razaosocial  \
# 1567              PREFEITURA MUNICIPAL DE EPITACIOLANDIA
# 6250                  PREFEITURA MUNICIPAL DE RIO BRANCO
# 9569             PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 11338                      PREFEITURA MUNICIPAL DE FEIJO
# 15144  DISTRITO SANITARIO ESPECIAL INDIGENA ALTO RIO ...
#
#                                 estalecimento_nofantasia  \
# 1567                             ESF JOAO ALVES DA SILVA
# 6250   DEPARTAMENTO DE VIGILANCIA EPIDEMIOLOGICA E AM...
# 9569    SECRETARIA MUNICIPAL DE SAUDE DE CRUZEIRO DO SUL
# 11338                  CENTRO DE SAUDE DIAMANTINO MACEDO
# 15144                  POLO BASE DE MARECHAL THAUMATURGO
#
#        estabelecimento_municipio_codigo estabelecimento_municipio_nome  \
# ...

# %%
#5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento,com os dados do estabelecimento  

nova_lista_estab=nova_lista_estab.drop_duplicates()

nova_lista_estab.shape
# Out:
# (18, 6)
