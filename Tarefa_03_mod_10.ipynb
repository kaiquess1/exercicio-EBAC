# %% [markdown]
# ### Tarefa 03

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv('/content/Profissao- Cientista de Dados_M10_support material.csv')

# %%
df=df.drop(columns=['Unnamed: 0'],axis=1)
df.set_index('index',inplace=True)
df.head()
# Out:
#          data_ref sexo  posse_de_veiculo  posse_de_imovel  qtd_filhos  \
# index
# 8682   2015-01-01    F             False             True           1
# 12830  2015-01-01    M              True             True           0
# 2885   2015-01-01    M              True             True           2
# 16168  2015-01-01    F              True            False           0
# 12438  2015-01-01    M             False            False           0
#
#         tipo_renda           educacao estado_civil tipo_residencia  idade  \
# index
# 8682   Assalariado         Secundário       Casado            Casa     36
# 12830   Empresário         Secundário       Casado            Casa     42
# 2885   Assalariado  Superior completo       Casado            Casa     31
# 16168   Empresário         Secundário       Casado            Casa     50
# 12438  Assalariado         Secundário       Casado            Casa     52
#
#        tempo_emprego  qt_pessoas_residencia    mau    renda
# index
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15000 entries, 8682 to 12895
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   data_ref               15000 non-null  object
#  1   sexo                   15000 non-null  object
#  2   posse_de_veiculo       15000 non-null  bool
#  3   posse_de_imovel        15000 non-null  bool
#  4   qtd_filhos             15000 non-null  int64
#  5   tipo_renda             15000 non-null  object
#  6   educacao               15000 non-null  object
#  7   estado_civil           15000 non-null  object
#  8   tipo_residencia        15000 non-null  object
#  9   idade                  15000 non-null  int64
#  10  tempo_emprego          12466 non-null  float64
#  11  qt_pessoas_residencia  15000 non-null  float64
#  12  mau                    15000 non-null  bool
#  13  renda                  15000 non-null  float64
# ...

# %%
qualitativa=df.select_dtypes(include='O')
qualitativa
# Out:
#          data_ref        tipo_renda           educacao estado_civil  \
# index
# 8682   2015-01-01       Assalariado         Secundário       Casado
# 12830  2015-01-01        Empresário         Secundário       Casado
# 2885   2015-01-01       Assalariado  Superior completo       Casado
# 16168  2015-01-01        Empresário         Secundário       Casado
# 12438  2015-01-01       Assalariado         Secundário       Casado
# ...           ...               ...                ...          ...
# 3678   2016-03-01       Assalariado         Secundário       Casado
# 3405   2016-03-01  Servidor público  Superior completo       Casado
# 7944   2016-03-01       Assalariado         Secundário       Casado
# 16019  2016-03-01  Servidor público  Superior completo       Casado
# 12895  2016-03-01       Assalariado         Secundário       Casado
#
#       tipo_residencia
# index
# 8682             Casa
# 12830            Casa
# 2885             Casa
# 16168            Casa
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime

# %% [markdown]
# * Questão 01

# %%
fig,ax=plt.subplots(figsize=(20,10),sharex=True)
ax=sns.countplot(x='data_ref',hue='educacao' ,data=qualitativa)

# %% [markdown]
# * Identificamos uma alteração no perfil da população na varivável **educação**

# %%
fig,ax=plt.subplots(figsize=(20,10),sharex=True)
ax=sns.countplot(x='data_ref',hue='tipo_renda' ,data=qualitativa)

# %%
fig,ax=plt.subplots(figsize=(20,10),sharex=True)
ax=sns.countplot(x='data_ref',hue='estado_civil' ,data=qualitativa)

# %%
fig,ax=plt.subplots(figsize=(20,10),sharex=True)
ax=sns.countplot(x='data_ref',hue='tipo_residencia' ,data=qualitativa)
#plt.legend(bbox_to_anchor=(1.05,1), loc=2,borderaxespad=0.)

# %% [markdown]
# * Questão 02

# %%
# Não entendi como resolveria a questão 02

# %%
qualitativa.info()
qualitativa['data_ref']=pd.to_datetime(qualitativa['data_ref'])
qualitativa
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15000 entries, 8682 to 12895
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   data_ref         15000 non-null  datetime64[ns]
#  1   tipo_renda       15000 non-null  object
#  2   educacao         15000 non-null  object
#  3   estado_civil     15000 non-null  object
#  4   tipo_residencia  15000 non-null  object
# dtypes: datetime64[ns](1), object(4)
# memory usage: 1.2+ MB
# <ipython-input-70-4c4fe3da8b17>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   qualitativa['data_ref']=pd.to_datetime(qualitativa['data_ref'])
#         data_ref        tipo_renda           educacao estado_civil  \
# index
# ...
